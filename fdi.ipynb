# %% [markdown]
# # Loading libraries

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# # Importing data

# %%
FDI2 = pd.read_excel('FDI2.xlsx')

# %% [markdown]
# # Exploring data

# %%
FDI2.head()
# Out:
#   payscode  codepays  Année           ide          toc        tcr  \
# 0      BGD         1   2004  4.489054e+08  38953960.63  59.512658
# 1      BGD         1   2005  7.605043e+08  51935441.53  64.327475
# 2      BGD         1   2006  4.565232e+08  59714312.41  68.933233
# 3      BGD         1   2007  6.510297e+08  64798835.89  68.874875
# 4      BGD         1   2008  1.328423e+09  62836842.93  68.598275
#
#           fbcf  climatdaffaire  scoreeasedoingbusiness       caff    edb  \
# 0  18286460936       47.380000                    70.0  63.380000  66.00
# 1  20071885132       42.400000                    70.0  70.066667  61.30
# 2  22056583775       50.916667                    70.0  72.800000  63.90
# 3  23632938587       40.266667                    70.0  69.450000  65.36
# 4  25952536543       36.650000                    70.0  71.450000  67.00
#
#     crp   BUF  invf  finfree         CM
# 0  0.11  55.0  50.0     70.0  10.671695
# 1  0.06  55.0  50.0     70.0   4.751541
# 2 -0.07  70.5  70.0     70.0   5.361124
# 3 -0.18  70.3  60.0     60.0  10.969166
# 4 -0.25  68.4  60.0     60.0  12.791560

# %%
FDI2.tail()
# Out:
#     payscode  codepays  Année           ide          toc       tcr  \
# 325      TUR        22   2014  1.333700e+10  35361166.84  2.188542
# 326      TUR        22   2015  1.927400e+10  34868314.46  2.720009
# 327      TUR        22   2016  1.395000e+10  34681331.76  3.020135
# 328      TUR        22   2017  1.154600e+10  34774823.11  3.648133
# 329      TUR        22   2018  1.306100e+10  34728077.44  4.828370
#
#              fbcf  climatdaffaire  scoreeasedoingbusiness  caff  edb  crp  \
# 325  292106000000       68.933333                  83.400   NaN  NaN  NaN
# 326  319228000000       67.200000                  77.500   NaN  NaN  NaN
# 327  326401000000       67.483333                  73.980   NaN  NaN  NaN
# 328  353331000000       66.566667                  72.900   NaN  NaN  NaN
# 329  351244000000       66.133333                  73.875   NaN  NaN  NaN
#
#      BUF  invf  finfree         CM
# 325  NaN   NaN      NaN  23.405529
# 326  NaN   NaN      NaN  21.851067
# 327  NaN   NaN      NaN  19.750290
# 328  NaN   NaN      NaN  26.486011
# 329  NaN   NaN      NaN  19.176135

# %% [markdown]
# # rename columns

# %%
FDI2.rename(columns = {'ide' : 'fdi', 'toc' : 'commercial_opening_rate', 'CM' : 'Stock Market'}, inplace = True)

# %%
FDI2.rename(columns = {'tcr' : 'Exchange_rate' , 'fbcf' : 'gross_fixed_capital_formation' ,  'climatdaffaire' : 'business_climate',   'cm' : 'stock_market'}, inplace = True)

# %% [markdown]
# I decided to drop the following columns because of ...

# %%
FDI3= FDI2.drop(['caff', 'edb', 'crp'], axis=1)

# %% [markdown]
# # lower case the variables

# %%
FDI3.columns = list(map(lambda x: x.lower(), FDI3.columns))
FDI3.columns.unique()
# Out:
# Index(['payscode', 'codepays', 'année', 'fdi', 'commercial_opening_rate',
#        'exchange_rate', 'gross_fixed_capital_formation', 'business_climate',
#        'scoreeasedoingbusiness', 'buf', 'invf', 'finfree', 'stock market'],
#       dtype='object')

# %% [markdown]
# # exploring the data afer modification

# %%
FDI3.shape
# Out:
# (330, 13)

# %%
FDI3.dtypes
# Out:
# payscode                          object
# codepays                           int64
# année                              int64
# fdi                              float64
# commercial_opening_rate          float64
# exchange_rate                    float64
# gross_fixed_capital_formation      int64
# business_climate                 float64
# scoreeasedoingbusiness           float64
# buf                              float64
# invf                             float64
# finfree                          float64
# stock market                     float64
# dtype: object

# %%
FDI3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   payscode                       330 non-null    object
#  1   codepays                       330 non-null    int64
#  2   année                          330 non-null    int64
#  3   fdi                            330 non-null    float64
#  4   commercial_opening_rate        330 non-null    float64
#  5   exchange_rate                  330 non-null    float64
#  6   gross_fixed_capital_formation  330 non-null    int64
#  7   business_climate               330 non-null    float64
#  8   scoreeasedoingbusiness         330 non-null    float64
#  9   buf                            165 non-null    float64
#  10  invf                           165 non-null    float64
#  11  finfree                        165 non-null    float64
#  12  stock market                   330 non-null    float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 33.6+ KB

# %%
list (FDI3 ['fdi'].unique())
# Out:
# [448905400.7,
#  760504265.8,
#  456523167.7,
#  651029738.1,
#  1328422987.0,
#  901286583.1,
#  1232258247.0,
#  1264725163.0,
#  1584403460.0,
#  2602962095.0,
#  2539190940.0,
#  2831152765.0,
#  2332724781.0,
#  1810395804.0,
#  2940222420.0,
#  3072550962.0,
#  4098122931.0,
#  7874476255.0,
#  13875270457.0,
#  10296720634.0,
#  3896664559.0,
#  1842900000.0,
#  2103810000.0,
#  1788110000.0,
#  1989040000.0,
#  1093600000.0,
#  2609370000.0,
#  1562800000.0,
#  2020340000.0,
#  1222580000.0,
#  18181190855.0,
#  15459981604.0,
#  19378093068.0,
#  44579492464.0,
#  50716402711.0,
#  31480932200.0,
#  82389933624.0,
#  102427000000.0,
#  92568379495.0,
#  75211028087.0,
#  87713987797.0,
#  60334050668.0,
#  73377909022.0,
#  68885072606.0,
#  78162572753.0,
#  68117272181.0,
#  104109000000.0,
#  124082000000.0,
#  156249000000.0,
#  171535000000.0,
#  131057000000.0,
#  243703000000.0,
#  280072000000.0,
#  241214000000.0,
#  290928000000.0,
#  268097000000.0,
#  242489000000.0,
#  174750000000.0,
#  166084000000.0,
#  203492000000.0,
#  881851385.0,
#  1156000000.0,
#  1841000000.0,
#  1686736540.0,
#  2638607034.0,
#  2746930734.0,
#  2300369124.0,
#  2571237025.0,
#  1500402453.0,
#  1691886708.0,
#  1502206171.0,
#  -537792920.9,
#  1638263954.0,
#  1200965280.0,
#  1506316886.0,
#  1253300000.0,
#  5375600000.0,
#  10042800000.0,
#  11578100000.0,
#  9494600000.0,
#  6711600000.0,
#  6385600000.0,
#  -482700000.0,
#  2797700000.0,
#  4192200000.0,
#  4612200000.0,
#  6925200000.0,
#  8106800000.0,
#  7408700000.0,
#  6797600000.0,
#  1896082770.0,
# buf                              165
# invf                             165
# finfree                          165
# stock market                       0
# dtype: int64

# %% [markdown]
# # Replacing the NAN values by the mean

# %%
FDI3[(FDI3['buf'].isna() == True) & (FDI3['invf'].isna()==True) & (FDI3['finfree'].isna()==True)]
display (FDI3)
# Out:
#     payscode  codepays  année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# 1        64.327475                    20071885132         42.400000
# 2        68.933233                    22056583775         50.916667
# 3        68.874875                    23632938587         40.266667
# 4        68.598275                    25952536543         36.650000
# ..             ...                            ...               ...
# 325       2.188542                   292106000000         68.933333
# 326       2.720009                   319228000000         67.200000
# 327       3.020135                   326401000000         67.483333
# 328       3.648133                   353331000000         66.566667
# 329       4.828370                   351244000000         66.133333
#
#      scoreeasedoingbusiness   buf  invf  finfree  stock market
# 0                    70.000  55.0  50.0     70.0     10.671695
# 1                    70.000  55.0  50.0     70.0      4.751541
# 2                    70.000  70.5  70.0     70.0      5.361124
# 3                    70.000  70.3  60.0     60.0     10.969166
# 4                    70.000  68.4  60.0     60.0     12.791560
# ..                      ...   ...   ...      ...           ...
# 325                  83.400   NaN   NaN      NaN     23.405529
# 326                  77.500   NaN   NaN      NaN     21.851067
# 327                  73.980   NaN   NaN      NaN     19.750290
# 328                  72.900   NaN   NaN      NaN     26.486011
# 329                  73.875   NaN   NaN      NaN     19.176135
#
# [330 rows x 13 columns]

# %%
FDI3['buf'].fillna(FDI3['buf'].mean(), inplace=True)

# %%
display(FDI3)
# Out:
#     payscode  codepays  année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# 1        64.327475                    20071885132         42.400000
# 2        68.933233                    22056583775         50.916667
# 3        68.874875                    23632938587         40.266667
# 4        68.598275                    25952536543         36.650000
# ..             ...                            ...               ...
# 325       2.188542                   292106000000         68.933333
# 326       2.720009                   319228000000         67.200000
# 327       3.020135                   326401000000         67.483333
# 328       3.648133                   353331000000         66.566667
# 329       4.828370                   351244000000         66.133333
#
#      scoreeasedoingbusiness        buf  invf  finfree  stock market
# 0                    70.000  55.000000  50.0     70.0     10.671695
# 1                    70.000  55.000000  50.0     70.0      4.751541
# 2                    70.000  70.500000  70.0     70.0      5.361124
# 3                    70.000  70.300000  60.0     60.0     10.969166
# 4                    70.000  68.400000  60.0     60.0     12.791560
# ..                      ...        ...   ...      ...           ...
# 325                  83.400  66.932121   NaN      NaN     23.405529
# 326                  77.500  66.932121   NaN      NaN     21.851067
# 327                  73.980  66.932121   NaN      NaN     19.750290
# 328                  72.900  66.932121   NaN      NaN     26.486011
# 329                  73.875  66.932121   NaN      NaN     19.176135
#
# [330 rows x 13 columns]

# %%
FDI3['invf'].fillna(FDI3['invf'].mean(), inplace=True)

# %%
FDI3['finfree'].fillna(FDI3['finfree'].mean(), inplace=True)

# %% [markdown]
# # Check again the missing values

# %%
FDI3.isna().sum()
# Out:
# payscode                         0
# codepays                         0
# année                            0
# fdi                              0
# commercial_opening_rate          0
# exchange_rate                    0
# gross_fixed_capital_formation    0
# business_climate                 0
# scoreeasedoingbusiness           0
# buf                              0
# invf                             0
# finfree                          0
# stock market                     0
# dtype: int64

# %% [markdown]
# we have here a clean data

# %% [markdown]
# # describing the data

# %%
FDI3.describe().T
# Out:
#                                count          mean           std  \
# codepays                       330.0  1.150000e+01  6.353923e+00
# année                          330.0  2.011000e+03  4.327055e+00
# fdi                            330.0  1.828205e+10  4.312849e+10
# commercial_opening_rate        330.0  6.454303e+07  1.170231e+08
# exchange_rate                  330.0  1.331637e+03  4.823952e+03
# gross_fixed_capital_formation  330.0  2.416401e+11  6.508859e+11
# business_climate               330.0  5.992981e+01  8.639142e+00
# scoreeasedoingbusiness         330.0  6.275875e+01  1.065464e+01
# buf                            330.0  6.693212e+01  7.137388e+00
# invf                           330.0  5.106061e+01  1.610088e+01
# finfree                        330.0  4.793939e+01  1.234009e+01
# stock market                   330.0  4.147970e+01  3.298583e+01
#
#                                         min           25%           50%  \
# codepays                       1.000000e+00  6.000000e+00  1.150000e+01
# année                          2.004000e+03  2.007000e+03  2.011000e+03
# fdi                           -5.377929e+08  1.818047e+09  4.576957e+09
# commercial_opening_rate       -6.412492e-01  1.577948e+07  3.510331e+07
# exchange_rate                  1.232142e+00  3.329896e+00  2.486804e+01
# gross_fixed_capital_formation  2.625409e+09  2.613547e+10  5.002675e+10
# business_climate               3.378333e+01  5.419167e+01  5.926667e+01
# scoreeasedoingbusiness         2.610000e+01  5.577375e+01  6.330000e+01
# buf                            4.000000e+01  6.693212e+01  6.693212e+01
# invf                           0.000000e+00  5.000000e+01  5.106061e+01
# finfree                        1.000000e+01  4.793939e+01  4.793939e+01
# stock market                   5.339774e-02  1.847838e+01  3.291624e+01
#
#                                         75%           max
# codepays                       1.700000e+01  2.200000e+01
# année                          2.015000e+03  2.018000e+03
# fdi                            1.326800e+10  2.909280e+11
# commercial_opening_rate        6.330626e+07  7.038409e+08
# exchange_rate                  7.921833e+01  4.086433e+04
# gross_fixed_capital_formation  1.882652e+11  4.414250e+12
# business_climate               6.659167e+01  7.495000e+01
# scoreeasedoingbusiness         7.081500e+01  8.610000e+01
# buf                            6.865000e+01  8.780000e+01
# invf                           5.106061e+01  9.000000e+01
# finfree                        5.000000e+01  7.000000e+01
# stock market                   5.383899e+01  1.680671e+02

# %% [markdown]
# # plotting

# %%
numericals = FDI3.select_dtypes(np.number)
display(numericals.head())
categoricals = FDI3.select_dtypes(object)
display(categoricals.head())
# Out:
#    codepays  année           fdi  commercial_opening_rate  exchange_rate  \
# 0         1   2004  4.489054e+08              38953960.63      59.512658
# 1         1   2005  7.605043e+08              51935441.53      64.327475
# 2         1   2006  4.565232e+08              59714312.41      68.933233
# 3         1   2007  6.510297e+08              64798835.89      68.874875
# 4         1   2008  1.328423e+09              62836842.93      68.598275
#
#    gross_fixed_capital_formation  business_climate  scoreeasedoingbusiness  \
# 0                    18286460936         47.380000                    70.0
# 1                    20071885132         42.400000                    70.0
# 2                    22056583775         50.916667                    70.0
# 3                    23632938587         40.266667                    70.0
# 4                    25952536543         36.650000                    70.0
#
#     buf  invf  finfree  stock market
# 0  55.0  50.0     70.0     10.671695
# 1  55.0  50.0     70.0      4.751541
# 2  70.5  70.0     70.0      5.361124
# 3  70.3  60.0     60.0     10.969166
# 4  68.4  60.0     60.0     12.791560
#   payscode
# 0      BGD
# 1      BGD
# 2      BGD
# 3      BGD
# 4      BGD

# %%
def numericals_plot(df):
    for i in df.columns:
        sns.histplot(x=i, data = df);
        plt.show()
    return
    
numericals_plot(numericals)

# %% [markdown]
# # Log transormation

# %% [markdown]
# Check if any of the log transformations changes the result.

# %%
numeric_FDI3 = FDI3.apply(lambda x: np.log(x) if np.issubdtype(x.dtype, np.number) else x)
# Out:
# C:\Users\NON\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\NON\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
display (numeric_FDI3)
# Out:
#     payscode  codepays     année        fdi  commercial_opening_rate  \
# 0        BGD  0.000000  7.602900  19.922323                17.477891
# 1        BGD  0.000000  7.603399  20.449492                17.765512
# 2        BGD  0.000000  7.603898  19.939150                17.905082
# 3        BGD  0.000000  7.604396  20.294066                17.986798
# 4        BGD  0.000000  7.604894  21.007258                17.956052
# ..       ...       ...       ...        ...                      ...
# 325      TUR  3.091042  7.607878  23.313808                17.381125
# 326      TUR  3.091042  7.608374  23.682023                17.367089
# 327      TUR  3.091042  7.608871  23.358745                17.361712
# 328      TUR  3.091042  7.609367  23.169605                17.364404
# 329      TUR  3.091042  7.609862  23.292897                17.363059
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0         4.086189                      23.629427          3.858200
# 1         4.163987                      23.722586          3.747148
# 2         4.233138                      23.816877          3.930190
# 3         4.232291                      23.885907          3.695524
# 4         4.228267                      23.979535          3.601413
# ..             ...                            ...               ...
# 325       0.783236                      26.400383          4.233140
# 326       1.000635                      26.489171          4.207673
# 327       1.105301                      26.511393          4.211881
# 328       1.294215                      26.590671          4.198204
# 329       1.574509                      26.584747          4.191673
#
#      scoreeasedoingbusiness       buf      invf   finfree  stock market
# 0                  4.248495  4.007333  3.912023  4.248495      2.367595
# 1                  4.248495  4.007333  3.912023  4.248495      1.558469
# 2                  4.248495  4.255613  4.248495  4.248495      1.679174
# 3                  4.248495  4.252772  4.094345  4.094345      2.395088
# 4                  4.248495  4.225373  4.094345  4.094345      2.548786
# ..                      ...       ...       ...       ...           ...
# 325                4.423648  4.203679  3.933013  3.869938      3.152972
# 326                4.350278  4.203679  3.933013  3.869938      3.084250
# 327                4.303795  4.203679  3.933013  3.869938      2.983168
# 328                4.289089  4.203679  3.933013  3.869938      3.276617
# 329                4.302374  4.203679  3.933013  3.869938      2.953667
#
# [330 rows x 13 columns]

# %%
numeric_FDI3.describe().T
# Out:
#                                count       mean       std        min  \
# codepays                       330.0   2.203236  0.804480   0.000000
# année                          330.0   7.606385  0.002152   7.602900
# fdi                            328.0  22.340273  1.577894  16.870063
# commercial_opening_rate        325.0  16.838959  3.237971  -2.374398
# exchange_rate                  330.0   3.275529  2.480418   0.208754
# gross_fixed_capital_formation  330.0  24.844106  1.545575  21.688502
# business_climate               330.0   4.082123  0.151820   3.519968
# scoreeasedoingbusiness         330.0   4.123277  0.185377   3.261935
# buf                            330.0   4.197650  0.112154   3.688879
# invf                           330.0       -inf       NaN       -inf
# finfree                        330.0   3.814729  0.389191   2.302585
# stock market                   330.0   3.250427  1.409164  -2.929987
#
#                                      25%        50%        75%        max
# codepays                        1.791759   2.441401   2.833213   3.091042
# année                           7.604396   7.606387   7.608374   7.609862
# fdi                            21.334348  22.254726  23.314961  26.396342
# commercial_opening_rate        16.657085  17.385396  17.970180  20.372063
# exchange_rate                   1.202940   3.187336   4.372208  10.618013
# gross_fixed_capital_formation  23.986486  24.635813  25.961106  29.115859
# business_climate                3.992527   4.082047   4.198579   4.316821
# scoreeasedoingbusiness          4.021303   4.147885   4.260071   4.455509
# buf                             4.203679   4.203679   4.229020   4.475062
# invf                            3.912023   3.933013   3.933013   4.499810
# finfree                         3.869938   3.869938   3.912023   4.248495
# stock market                    2.916595   3.493966   3.985987   5.124363

# %% [markdown]
# # PLOTTING with log

# %%
import seaborn as sns
sns.pairplot(numeric_FDI3[['fdi','stock market' ]])

# %%
def numericals_plot2(df):
    for i in df.columns:
        sns.histplot(x=i, data = df, bins=10);
        plt.show()
    
numericals_plot2(numeric_FDI3)

# %% [markdown]
# # correlation

# %%
import seaborn as sb
dataplot=sb.heatmap(numeric_FDI3.corr(), annot=True,  )
plt.gcf().set_size_inches(15, 8)

# %%
numeric_FDI3 = numeric_FDI3[['fdi','gross_fixed_capital_formation','invf','finfree', 'stock market']].corr()
numeric_FDI3
# Out:
#                                     fdi  gross_fixed_capital_formation  \
# fdi                            1.000000                       0.863739
# gross_fixed_capital_formation  0.863739                       1.000000
# invf                          -0.166544                      -0.129064
# finfree                       -0.146985                      -0.231641
# stock market                   0.276211                       0.150959
#
#                                    invf   finfree  stock market
# fdi                           -0.166544 -0.146985      0.276211
# gross_fixed_capital_formation -0.129064 -0.231641      0.150959
# invf                           1.000000  0.748409      0.356951
# finfree                        0.748409  1.000000      0.696000
# stock market                   0.356951  0.696000      1.000000

# %% [markdown]
#  we have multicolinearity here with gross_fixed_capital_formation . We need to drop one of these columns.
# We will drop gross_fixed_capital_formation

# %%
# we have multicolinearity here with gross_fixed_capital_formation . We need to drop one of these columns. 
# We will drop gross_fixed_capital_formation 

numeric_FDI3 = numeric_FDI3.drop(['gross_fixed_capital_formation'], axis=1)

# %% [markdown]
# # Ploting fdi

# %%
sns.displot(numeric_FDI3['fdi'])
plt.show()

# %%
sns.boxplot(x=numeric_FDI3['fdi'])
plt.show()

# %% [markdown]
# # Linear regression

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
y = numeric_FDI3['fdi']
X = numeric_FDI3[['stock market']]

# %%
y = numeric_FDI3['fdi']
X = numeric_FDI3[['stock market']] 
lm = linear_model.LinearRegression()
lm.fit(X,y)
# Out:
# LinearRegression()

# %%
lm.fit(X,y) # X is the column that we want to use to make predictions. y is the column that we want to predict
print(lm.intercept_) # b_0
print(lm.coef_) # coefficients is an array because later we will see we can have more than one dimension for our gradient
# Out:
# 0.7624315861198119
# [-0.80066156]

# %%
regression_line = lm.intercept_ + lm.coef_[0]*numeric_FDI3['stock market'] # b_0 + b_1 * x
plt.plot(numeric_FDI3['stock market'], regression_line, c = 'orange')
sns.scatterplot(x='stock market',y='fdi',data=numeric_FDI3)
plt.show()

# %%
regression_line = lm.intercept_ + lm.coef_[0] * numeric_FDI3['stock market'] # b_0 + b_1 * x
plt.plot(numeric_FDI3['stock market'],regression_line, c = 'orange')
plt.scatter(numeric_FDI3['stock market'],numeric_FDI3['fdi'], c = 'blue')
plt.show()

# %%
sns.scatterplot(y = logits,x = X_train_scaled['fdi']);
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18924/2477693977.py in <module>
# ----> 1 sns.scatterplot(y = logits,x = X_train_scaled['fdi']);
#       2 plt.show()
#
# NameError: name 'logits' is not defined

# %% [markdown]
# # split

# %%
y = numeric_FDI3['fdi']
X = numeric_FDI3[['stock market']] 

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# PowerTransformer()
MinMaxtransformer = MinMaxScaler()
MinMaxtransformer.fit(X_train)

X_train_scaled = MinMaxtransformer.transform(X_train)
X_test_scaled  = MinMaxtransformer.transform(X_test)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled  = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %% [markdown]
# # regression

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

y = y_train
X = X_train_scaled

lm = linear_model.LinearRegression()
lm.fit(X,y)
print(lm.intercept_)
print(lm.coef_)
print(lm.score(X,y))
# Out:
# 0.9724310620847076
# [-0.67741089]
# 0.9039311217402191

# %% [markdown]
# # Description

# %%
#R2.
#MSE.
#RMSE.
#MAE.
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

lm = linear_model.LinearRegression()
lm.fit(X,y)
print(round(lm.intercept_,1))
print(lm.coef_.round(1))
print("r^2: ",round(lm.score(X_train_scaled,y_train),2))
# Out:
# 1.0
# [-0.7]
# r^2:  0.9
