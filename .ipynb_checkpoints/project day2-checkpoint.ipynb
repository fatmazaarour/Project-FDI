# %% [markdown]
# # Loading libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# # Importing data

# %%
FDI2 = pd.read_excel('FDI2.xlsx')

# %% [markdown]
# # Exploring data

# %%
FDI2.head()
# Out:
#   payscode  codepays  Année           ide          toc        tcr  \
# 0      BGD         1   2004  4.489054e+08  38953960.63  59.512658
# 1      BGD         1   2005  7.605043e+08  51935441.53  64.327475
# 2      BGD         1   2006  4.565232e+08  59714312.41  68.933233
# 3      BGD         1   2007  6.510297e+08  64798835.89  68.874875
# 4      BGD         1   2008  1.328423e+09  62836842.93  68.598275
#
#           fbcf  climatdaffaire  scoreeasedoingbusiness       caff    edb  \
# 0  18286460936       47.380000                    70.0  63.380000  66.00
# 1  20071885132       42.400000                    70.0  70.066667  61.30
# 2  22056583775       50.916667                    70.0  72.800000  63.90
# 3  23632938587       40.266667                    70.0  69.450000  65.36
# 4  25952536543       36.650000                    70.0  71.450000  67.00
#
#     crp   BUF  invf  finfree         CM
# 0  0.11  55.0  50.0     70.0  10.671695
# 1  0.06  55.0  50.0     70.0   4.751541
# 2 -0.07  70.5  70.0     70.0   5.361124
# 3 -0.18  70.3  60.0     60.0  10.969166
# 4 -0.25  68.4  60.0     60.0  12.791560

# %%
FDI2.tail()
# Out:
#     payscode  codepays  Année           ide          toc       tcr  \
# 325      TUR        22   2014  1.333700e+10  35361166.84  2.188542
# 326      TUR        22   2015  1.927400e+10  34868314.46  2.720009
# 327      TUR        22   2016  1.395000e+10  34681331.76  3.020135
# 328      TUR        22   2017  1.154600e+10  34774823.11  3.648133
# 329      TUR        22   2018  1.306100e+10  34728077.44  4.828370
#
#              fbcf  climatdaffaire  scoreeasedoingbusiness  caff  edb  crp  \
# 325  292106000000       68.933333                  83.400   NaN  NaN  NaN
# 326  319228000000       67.200000                  77.500   NaN  NaN  NaN
# 327  326401000000       67.483333                  73.980   NaN  NaN  NaN
# 328  353331000000       66.566667                  72.900   NaN  NaN  NaN
# 329  351244000000       66.133333                  73.875   NaN  NaN  NaN
#
#      BUF  invf  finfree         CM
# 325  NaN   NaN      NaN  23.405529
# 326  NaN   NaN      NaN  21.851067
# 327  NaN   NaN      NaN  19.750290
# 328  NaN   NaN      NaN  26.486011
# 329  NaN   NaN      NaN  19.176135

# %% [markdown]
# # rename columns

# %%
FDI2.rename(columns = {'Année': 'year' , 'codepays': 'ID_countries' , 'ide' : 'fdi', 'toc' : 'commercial_opening_rate', 'CM' : 'Stock Market'}, inplace = True)

# %%
FDI2.rename(columns = {'tcr' : 'Exchange_rate' , 'fbcf' : 'gross_fixed_capital_formation' ,  'climatdaffaire' : 'business_climate',   'cm' : 'stock_market'}, inplace = True)

# %% [markdown]
# # Convert ID_countries and year to string

# %%
FDI2['ID_countries'] = FDI2['ID_countries'].astype('string')
FDI2.dtypes
# Out:
# payscode                          object
# ID_countries                      string
# year                               int64
# fdi                              float64
# commercial_opening_rate          float64
# Exchange_rate                    float64
# gross_fixed_capital_formation      int64
# business_climate                 float64
# scoreeasedoingbusiness           float64
# caff                             float64
# edb                              float64
# crp                              float64
# BUF                              float64
# invf                             float64
# finfree                          float64
# Stock Market                     float64
# dtype: object

# %%
FDI2['year'] = FDI2['year'].astype('string')
FDI2.dtypes
# Out:
# payscode                          object
# ID_countries                      string
# year                              string
# fdi                              float64
# commercial_opening_rate          float64
# Exchange_rate                    float64
# gross_fixed_capital_formation      int64
# business_climate                 float64
# scoreeasedoingbusiness           float64
# caff                             float64
# edb                              float64
# crp                              float64
# BUF                              float64
# invf                             float64
# finfree                          float64
# Stock Market                     float64
# dtype: object

# %% [markdown]
# # convert year to datetime

# %%
FDI2['year'] = pd.to_datetime(FDI2['year'])
FDI2.dtypes
# Out:
# payscode                                 object
# ID_countries                             string
# year                             datetime64[ns]
# fdi                                     float64
# commercial_opening_rate                 float64
# Exchange_rate                           float64
# gross_fixed_capital_formation             int64
# business_climate                        float64
# scoreeasedoingbusiness                  float64
# caff                                    float64
# edb                                     float64
# crp                                     float64
# BUF                                     float64
# invf                                    float64
# finfree                                 float64
# Stock Market                            float64
# dtype: object

# %%
FDI2.head()
# Out:
#   payscode ID_countries       year           fdi  commercial_opening_rate  \
# 0      BGD            1 2004-01-01  4.489054e+08              38953960.63
# 1      BGD            1 2005-01-01  7.605043e+08              51935441.53
# 2      BGD            1 2006-01-01  4.565232e+08              59714312.41
# 3      BGD            1 2007-01-01  6.510297e+08              64798835.89
# 4      BGD            1 2008-01-01  1.328423e+09              62836842.93
#
#    Exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0      59.512658                    18286460936         47.380000
# 1      64.327475                    20071885132         42.400000
# 2      68.933233                    22056583775         50.916667
# 3      68.874875                    23632938587         40.266667
# 4      68.598275                    25952536543         36.650000
#
#    scoreeasedoingbusiness       caff    edb   crp   BUF  invf  finfree  \
# 0                    70.0  63.380000  66.00  0.11  55.0  50.0     70.0
# 1                    70.0  70.066667  61.30  0.06  55.0  50.0     70.0
# 2                    70.0  72.800000  63.90 -0.07  70.5  70.0     70.0
# 3                    70.0  69.450000  65.36 -0.18  70.3  60.0     60.0
# 4                    70.0  71.450000  67.00 -0.25  68.4  60.0     60.0
#
#    Stock Market
# 0     10.671695
# 1      4.751541
# 2      5.361124
# 3     10.969166
# 4     12.791560

# %% [markdown]
# I decided to drop the following columns because of ...

# %%
FDI3= FDI2.drop(['caff', 'edb', 'crp'], axis=1)

# %%
display (FDI3)
# Out:
#     payscode ID_countries       year           fdi  commercial_opening_rate  \
# 0        BGD            1 2004-01-01  4.489054e+08              38953960.63
# 1        BGD            1 2005-01-01  7.605043e+08              51935441.53
# 2        BGD            1 2006-01-01  4.565232e+08              59714312.41
# 3        BGD            1 2007-01-01  6.510297e+08              64798835.89
# 4        BGD            1 2008-01-01  1.328423e+09              62836842.93
# ..       ...          ...        ...           ...                      ...
# 325      TUR           22 2014-01-01  1.333700e+10              35361166.84
# 326      TUR           22 2015-01-01  1.927400e+10              34868314.46
# 327      TUR           22 2016-01-01  1.395000e+10              34681331.76
# 328      TUR           22 2017-01-01  1.154600e+10              34774823.11
# 329      TUR           22 2018-01-01  1.306100e+10              34728077.44
#
#      Exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# 1        64.327475                    20071885132         42.400000
# 2        68.933233                    22056583775         50.916667
# 3        68.874875                    23632938587         40.266667
# 4        68.598275                    25952536543         36.650000
# ..             ...                            ...               ...
# 325       2.188542                   292106000000         68.933333
# 326       2.720009                   319228000000         67.200000
# 327       3.020135                   326401000000         67.483333
# 328       3.648133                   353331000000         66.566667
# 329       4.828370                   351244000000         66.133333
#
#      scoreeasedoingbusiness   BUF  invf  finfree  Stock Market
# 0                    70.000  55.0  50.0     70.0     10.671695
# 1                    70.000  55.0  50.0     70.0      4.751541
# 2                    70.000  70.5  70.0     70.0      5.361124
# 3                    70.000  70.3  60.0     60.0     10.969166
# 4                    70.000  68.4  60.0     60.0     12.791560
# ..                      ...   ...   ...      ...           ...
# 325                  83.400   NaN   NaN      NaN     23.405529
# 326                  77.500   NaN   NaN      NaN     21.851067
# 327                  73.980   NaN   NaN      NaN     19.750290
# 328                  72.900   NaN   NaN      NaN     26.486011
# 329                  73.875   NaN   NaN      NaN     19.176135
#
# [330 rows x 13 columns]

# %% [markdown]
# # lower case the variables

# %%
FDI3.columns = list(map(lambda x: x.lower(), FDI3.columns))
FDI3.columns.unique()
# Out:
# Index(['payscode', 'id_countries', 'year', 'fdi', 'commercial_opening_rate',
#        'exchange_rate', 'gross_fixed_capital_formation', 'business_climate',
#        'scoreeasedoingbusiness', 'buf', 'invf', 'finfree', 'stock market'],
#       dtype='object')

# %% [markdown]
# # exploring the data afer modification

# %%
FDI3.shape
# Out:
# (330, 13)

# %%
FDI3.dtypes
# Out:
# payscode                                 object
# id_countries                             string
# year                             datetime64[ns]
# fdi                                     float64
# commercial_opening_rate                 float64
# exchange_rate                           float64
# gross_fixed_capital_formation             int64
# business_climate                        float64
# scoreeasedoingbusiness                  float64
# buf                                     float64
# invf                                    float64
# finfree                                 float64
# stock market                            float64
# dtype: object

# %%
FDI3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   payscode                       330 non-null    object
#  1   id_countries                   330 non-null    string
#  2   year                           330 non-null    datetime64[ns]
#  3   fdi                            330 non-null    float64
#  4   commercial_opening_rate        330 non-null    float64
#  5   exchange_rate                  330 non-null    float64
#  6   gross_fixed_capital_formation  330 non-null    int64
#  7   business_climate               330 non-null    float64
#  8   scoreeasedoingbusiness         330 non-null    float64
#  9   buf                            165 non-null    float64
#  10  invf                           165 non-null    float64
#  11  finfree                        165 non-null    float64
#  12  stock market                   330 non-null    float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1), string(1)
# memory usage: 33.6+ KB

# %%
list (FDI3 ['fdi'].unique())
# Out:
# [448905400.7,
#  760504265.8,
#  456523167.7,
#  651029738.1,
#  1328422987.0,
#  901286583.1,
#  1232258247.0,
#  1264725163.0,
#  1584403460.0,
#  2602962095.0,
#  2539190940.0,
#  2831152765.0,
#  2332724781.0,
#  1810395804.0,
#  2940222420.0,
#  3072550962.0,
#  4098122931.0,
#  7874476255.0,
#  13875270457.0,
#  10296720634.0,
#  3896664559.0,
#  1842900000.0,
#  2103810000.0,
#  1788110000.0,
#  1989040000.0,
#  1093600000.0,
#  2609370000.0,
#         8.92757918e+09,  2.81018439e+09,  8.04550838e+09,  1.33986783e+10,
#         5.92147522e+08,  7.12714847e+08,  3.23990909e+09,  1.51534504e+09,
#         2.60067498e+09,  1.52524486e+09,  1.33449770e+09,  4.32666012e+08,
#         1.55426913e+09,  1.05862258e+09,  1.02475444e+09,  9.70521889e+08,
#         6.22569482e+08,  8.10936483e+08,  9.88942901e+08,  2.78500000e+09,
#         1.00310000e+10,  2.01850000e+10,  2.20470000e+10,  1.98510000e+10,
#         8.58500000e+09,  9.09900000e+09,  1.61820000e+10,  1.37440000e+10,
#         1.35630000e+10,  1.33370000e+10,  1.92740000e+10,  1.39500000e+10,
#         1.15460000e+10,  1.30610000e+10])

# %% [markdown]
# # cheking missing values

# %%
FDI3.isna().sum()
# Out:
# payscode                           0
# id_countries                       0
# year                               0
# fdi                                0
# commercial_opening_rate            0
# exchange_rate                      0
# gross_fixed_capital_formation      0
# business_climate                   0
# scoreeasedoingbusiness             0
# buf                              165
# invf                             165
# finfree                          165
# stock market                       0
# dtype: int64

# %% [markdown]
# # Replacing the NAN values by the median

# %%
FDI3[(FDI3['buf'].isna() == True) & (FDI3['invf'].isna()==True) & (FDI3['finfree'].isna()==True)]
display (FDI3)
# Out:
#     payscode id_countries       year           fdi  commercial_opening_rate  \
# 0        BGD            1 2004-01-01  4.489054e+08              38953960.63
# 1        BGD            1 2005-01-01  7.605043e+08              51935441.53
# 2        BGD            1 2006-01-01  4.565232e+08              59714312.41
# 3        BGD            1 2007-01-01  6.510297e+08              64798835.89
# 4        BGD            1 2008-01-01  1.328423e+09              62836842.93
# ..       ...          ...        ...           ...                      ...
# 325      TUR           22 2014-01-01  1.333700e+10              35361166.84
# 326      TUR           22 2015-01-01  1.927400e+10              34868314.46
# 327      TUR           22 2016-01-01  1.395000e+10              34681331.76
# 328      TUR           22 2017-01-01  1.154600e+10              34774823.11
# 329      TUR           22 2018-01-01  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# 1        64.327475                    20071885132         42.400000
# 2        68.933233                    22056583775         50.916667
# 3        68.874875                    23632938587         40.266667
# 4        68.598275                    25952536543         36.650000
# ..             ...                            ...               ...
# 325       2.188542                   292106000000         68.933333
# 326       2.720009                   319228000000         67.200000
# 327       3.020135                   326401000000         67.483333
# 328       3.648133                   353331000000         66.566667
# 329       4.828370                   351244000000         66.133333
#
#      scoreeasedoingbusiness   buf  invf  finfree  stock market
# 0                    70.000  55.0  50.0     70.0     10.671695
# 1                    70.000  55.0  50.0     70.0      4.751541
# 2                    70.000  70.5  70.0     70.0      5.361124
# 3                    70.000  70.3  60.0     60.0     10.969166
# 4                    70.000  68.4  60.0     60.0     12.791560
# ..                      ...   ...   ...      ...           ...
# 325                  83.400   NaN   NaN      NaN     23.405529
# 326                  77.500   NaN   NaN      NaN     21.851067
# 327                  73.980   NaN   NaN      NaN     19.750290
# 328                  72.900   NaN   NaN      NaN     26.486011
# 329                  73.875   NaN   NaN      NaN     19.176135
#
# [330 rows x 13 columns]

# %%
FDI3['buf'].fillna(FDI3['buf'].median(), inplace=True)

# %%
display(FDI3)
# Out:
#     payscode id_countries       year           fdi  commercial_opening_rate  \
# 0        BGD            1 2004-01-01  4.489054e+08              38953960.63
# 1        BGD            1 2005-01-01  7.605043e+08              51935441.53
# 2        BGD            1 2006-01-01  4.565232e+08              59714312.41
# 3        BGD            1 2007-01-01  6.510297e+08              64798835.89
# 4        BGD            1 2008-01-01  1.328423e+09              62836842.93
# ..       ...          ...        ...           ...                      ...
# 325      TUR           22 2014-01-01  1.333700e+10              35361166.84
# 326      TUR           22 2015-01-01  1.927400e+10              34868314.46
# 327      TUR           22 2016-01-01  1.395000e+10              34681331.76
# 328      TUR           22 2017-01-01  1.154600e+10              34774823.11
# 329      TUR           22 2018-01-01  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# 1        64.327475                    20071885132         42.400000
# 2        68.933233                    22056583775         50.916667
# 3        68.874875                    23632938587         40.266667
# 4        68.598275                    25952536543         36.650000
# ..             ...                            ...               ...
# 325       2.188542                   292106000000         68.933333
# 326       2.720009                   319228000000         67.200000
# 327       3.020135                   326401000000         67.483333
# 328       3.648133                   353331000000         66.566667
# 329       4.828370                   351244000000         66.133333
#
#      scoreeasedoingbusiness   buf  invf  finfree  stock market
# 0                    70.000  55.0  50.0     70.0     10.671695
# 1                    70.000  55.0  50.0     70.0      4.751541
# 2                    70.000  70.5  70.0     70.0      5.361124
# 3                    70.000  70.3  60.0     60.0     10.969166
# 4                    70.000  68.4  60.0     60.0     12.791560
# ..                      ...   ...   ...      ...           ...
# 325                  83.400  68.7   NaN      NaN     23.405529
# 326                  77.500  68.7   NaN      NaN     21.851067
# 327                  73.980  68.7   NaN      NaN     19.750290
# 328                  72.900  68.7   NaN      NaN     26.486011
# 329                  73.875  68.7   NaN      NaN     19.176135
#
# [330 rows x 13 columns]

# %%
FDI3['invf'].fillna(FDI3['invf'].median(), inplace=True)

# %%
FDI3['finfree'].fillna(FDI3['finfree'].median(), inplace=True)

# %% [markdown]
# # Check again the missing values

# %%
FDI3.isna().sum()
# Out:
# payscode                         0
# id_countries                     0
# year                             0
# fdi                              0
# commercial_opening_rate          0
# exchange_rate                    0
# gross_fixed_capital_formation    0
# business_climate                 0
# scoreeasedoingbusiness           0
# buf                              0
# invf                             0
# finfree                          0
# stock market                     0
# dtype: int64

# %% [markdown]
# we have here a clean data

# %% [markdown]
# # describing the data

# %%
FDI3.describe().T
# Out:
#                                count          mean           std  \
# fdi                            330.0  1.828205e+10  4.312849e+10
# commercial_opening_rate        330.0  6.454303e+07  1.170231e+08
# exchange_rate                  330.0  1.331637e+03  4.823952e+03
# gross_fixed_capital_formation  330.0  2.416401e+11  6.508859e+11
# business_climate               330.0  5.992981e+01  8.639142e+00
# scoreeasedoingbusiness         330.0  6.275875e+01  1.065464e+01
# buf                            330.0  6.781606e+01  7.192081e+00
# invf                           330.0  5.053030e+01  1.610964e+01
# finfree                        330.0  4.896970e+01  1.238316e+01
# stock market                   330.0  4.147970e+01  3.298583e+01
#
#                                         min           25%           50%  \
# fdi                           -5.377929e+08  1.818047e+09  4.576957e+09
# commercial_opening_rate       -6.412492e-01  1.577948e+07  3.510331e+07
# exchange_rate                  1.232142e+00  3.329896e+00  2.486804e+01
# gross_fixed_capital_formation  2.625409e+09  2.613547e+10  5.002675e+10
# business_climate               3.378333e+01  5.419167e+01  5.926667e+01
# scoreeasedoingbusiness         2.610000e+01  5.577375e+01  6.330000e+01
# buf                            4.000000e+01  6.870000e+01  6.870000e+01
# invf                           0.000000e+00  5.000000e+01  5.000000e+01
# finfree                        1.000000e+01  5.000000e+01  5.000000e+01
# stock market                   5.339774e-02  1.847838e+01  3.291624e+01
#
#                                         75%           max
# fdi                            1.326800e+10  2.909280e+11
# commercial_opening_rate        6.330626e+07  7.038409e+08
# exchange_rate                  7.921833e+01  4.086433e+04
# gross_fixed_capital_formation  1.882652e+11  4.414250e+12
# business_climate               6.659167e+01  7.495000e+01
# scoreeasedoingbusiness         7.081500e+01  8.610000e+01
# buf                            6.870000e+01  8.780000e+01
# invf                           5.000000e+01  9.000000e+01
# finfree                        5.000000e+01  7.000000e+01
# stock market                   5.383899e+01  1.680671e+02

# %% [markdown]
# # number and object

# %%
numericals = FDI3.select_dtypes(np.number)
display(numericals.head())
categoricals = FDI3.select_dtypes(object)
display(categoricals.head())
# Out:
#             fdi  commercial_opening_rate  exchange_rate  \
# 0  4.489054e+08              38953960.63      59.512658
# 1  7.605043e+08              51935441.53      64.327475
# 2  4.565232e+08              59714312.41      68.933233
# 3  6.510297e+08              64798835.89      68.874875
# 4  1.328423e+09              62836842.93      68.598275
#
#    gross_fixed_capital_formation  business_climate  scoreeasedoingbusiness  \
# 0                    18286460936         47.380000                    70.0
# 1                    20071885132         42.400000                    70.0
# 2                    22056583775         50.916667                    70.0
# 3                    23632938587         40.266667                    70.0
# 4                    25952536543         36.650000                    70.0
#
#     buf  invf  finfree  stock market
# 0  55.0  50.0     70.0     10.671695
# 1  55.0  50.0     70.0      4.751541
# 2  70.5  70.0     70.0      5.361124
# 3  70.3  60.0     60.0     10.969166
# 4  68.4  60.0     60.0     12.791560
#   payscode
# 0      BGD
# 1      BGD
# 2      BGD
# 3      BGD
# 4      BGD

# %% [markdown]
# # plotting

# %%
import matplotlib.pyplot as plt
def numericals_plot(df):
    for i in df.columns:
        sns.histplot(x=i, data = df);
        plt.show()
    return
    
numericals_plot(numericals)

# %% [markdown]
# # power transormation

# %% [markdown]
# Check if any of the log transformations changes the result.

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
pt.fit(numericals)
numeric_FDI3 = pd.DataFrame(pt.transform(numericals), columns = numericals.columns  )
numeric_FDI3.head()
# Out:
#         fdi  commercial_opening_rate  exchange_rate  \
# 0 -0.444693                 0.091316       0.587494
# 1 -0.431908                 0.305318       0.619904
# 2 -0.444369                 0.414890       0.648266
# 3 -0.436306                 0.480856       0.647921
# 4 -0.410158                 0.455876       0.646282
#
#    gross_fixed_capital_formation  business_climate  scoreeasedoingbusiness  \
# 0                      -0.774379         -1.417695                0.661596
# 1                      -0.707284         -1.895417                0.661596
# 2                      -0.639883         -1.055946                0.661596
# 3                      -0.590864         -2.088493                0.661596
# 4                      -0.524810         -2.399586                0.661596
#
#         buf      invf   finfree  stock market
# 0 -1.696496 -0.079910  2.400019     -1.081706
# 1 -1.696496 -0.079910  2.400019     -1.580889
# 2  0.325340  1.271784  2.400019     -1.517545
# 3  0.294923  0.582550  1.043553     -1.061439
# 4  0.011750  0.582550  1.043553     -0.943724

# %%
# numeric_FDI3 = FDI3.apply(lambda x: np.log(x) if np.issubdtype(x.dtype, np.number) else x)

# %%
(numeric_FDI3).isna().sum()
# Out:
# fdi                              0
# commercial_opening_rate          0
# exchange_rate                    0
# gross_fixed_capital_formation    0
# business_climate                 0
# scoreeasedoingbusiness           0
# buf                              0
# invf                             0
# finfree                          0
# stock market                     0
# dtype: int64

# %%
numeric_FDI3.describe().T
# Out:
#                                count          mean       std       min  \
# fdi                            330.0  5.744563e-17  1.001519 -3.671186
# commercial_opening_rate        330.0 -7.175447e-17  1.001519 -2.726421
# exchange_rate                  330.0  9.251859e-17  1.001519 -1.527504
# gross_fixed_capital_formation  330.0  4.642751e-16  1.001519 -2.293179
# business_climate               330.0  1.685520e-16  1.001519 -2.631364
# scoreeasedoingbusiness         330.0  2.462677e-16  1.001519 -2.735960
# buf                            330.0 -6.538961e-16  1.001519 -3.044600
# invf                           330.0 -8.503299e-17  1.001519 -2.722715
# finfree                        330.0 -3.545985e-16  1.001519 -2.305700
# stock market                   330.0 -1.147230e-16  1.001519 -2.359208
#
#                                     25%       50%       75%       max
# fdi                           -0.392375 -0.300387 -0.045516  5.781305
# commercial_opening_rate       -0.488424  0.017606  0.461905  3.148435
# exchange_rate                 -0.964542  0.170815  0.704049  2.024589
# gross_fixed_capital_formation -0.519930 -0.075541  0.762421  2.431483
# business_climate              -0.704674 -0.130020  0.762803  1.870386
# scoreeasedoingbusiness        -0.716744 -0.019406  0.748255  2.524387
# buf                            0.055768  0.055768  0.055768  3.409155
# invf                          -0.079910 -0.079910 -0.079910  2.719491
# finfree                       -0.071074 -0.071074 -0.071074  2.400019
# stock market                  -0.629804 -0.033728  0.591233  2.573010

# %% [markdown]
# # PLOTTING with transf

# %%
import seaborn as sns
sns.pairplot(numeric_FDI3[['fdi','stock market' ]])

# %%
def numericals_plot2(df):
    for i in df.columns:
        sns.histplot(x=i, data = df, bins=10);
        plt.show()
    
numericals_plot2(numeric_FDI3)

# %% [markdown]
# # correlation

# %%
import seaborn as sb
dataplot=sb.heatmap(numeric_FDI3.corr(), annot=True,  )
plt.gcf().set_size_inches(15, 8)

# %%
#corr_FDI3 = numeric_FDI3[['fdi','gross_fixed_capital_formation','invf','finfree', 'stock market']].corr()
#corr_FDI3

# %% [markdown]
#  we have multicolinearity here with gross_fixed_capital_formation . We need to drop one of these columns.
# We will drop gross_fixed_capital_formation

# %%
# we have multicolinearity here with gross_fixed_capital_formation . We need to drop one of these columns. 
# We will drop gross_fixed_capital_formation 

# numeric_FDI3 = numeric_FDI3.drop(['gross_fixed_capital_formation'], axis=1)

# %% [markdown]
# # Ploting fdi

# %%
sns.displot(numeric_FDI3['fdi'])
plt.show()

# %%
sns.boxplot(x=numeric_FDI3['fdi'])
plt.show()

# %%
iqr = np.percentile(numeric_FDI3['fdi'],75) - np.percentile(numeric_FDI3['fdi'],25)
upper_limit = np.percentile(numeric_FDI3['fdi'],75) + 1.5*iqr
lower_limit = np.percentile(numeric_FDI3['fdi'],25) - 1.5*iqr

# %%
numeric_FDI3 = numeric_FDI3[(numeric_FDI3['fdi']>lower_limit) & (numeric_FDI3['fdi']<upper_limit)]

# %%
sns.displot(numeric_FDI3['fdi'])

# %%
sns.boxplot(x=numeric_FDI3['fdi'])
plt.show()

# %%
#regression_line = lm.intercept_ + lm.coef_[0]*numeric_FDI3['stock market'] # b_0 + b_1 * x
#plt.plot(numeric_FDI3['stock market'], regression_line, c = 'orange')
#sns.scatterplot(x='stock market',y='fdi',data=numeric_FDI3)
#plt.show()

# %% [markdown]
# # split

# %%
y = numeric_FDI3['fdi']
X = numeric_FDI3[['stock market']] 

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# PowerTransformer()
#MinMaxtransformer = MinMaxScaler()
#MinMaxtransformer.fit(X_train)

#X_train_scaled = MinMaxtransformer.transform(X_train)
#X_test_scaled  = MinMaxtransformer.transform(X_test)

#X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
#X_test_scaled  = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
from sklearn.preprocessing import PowerTransformer
powertransformer = PowerTransformer()
powertransformer.fit(X_train)
#print(powertransformer.lambdas_)

X_train_scaled = powertransformer.transform(X_train)
X_test_scaled  = powertransformer.transform(X_test)

X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled_df  = pd.DataFrame(X_test_scaled, columns=X_test.columns)
# Out:
# [0.58374078 1.27996325 1.04170799 1.08685012 0.90073222 1.0145636
#  1.02546959 0.95129579]

# %% [markdown]
# # regression

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

#y = y_train
#X = X_train_scaled_df

lm = linear_model.LinearRegression()
lm.fit(X_train_scaled_df,y_train)
print(lm.intercept_)
print(lm.coef_)
print(lm.score(X,y))
# Out:
# -0.25826797913156574
# [ 0.000256    0.15761412  0.07573173 -0.01395954  0.00598328  0.02031759
#   0.00777031  0.01199388]
# 0.5973656502248083

# %%
X_train_scaled_df.describe()
# Out:
#        commercial_opening_rate  gross_fixed_capital_formation  \
# count             2.170000e+02                   2.170000e+02
# mean              4.092988e-18                   6.179453e-18
# std               1.002312e+00                   1.002312e+00
# min              -2.507002e+00                  -2.242070e+00
# 25%              -4.458292e-01                  -5.279291e-01
# 50%               1.054069e-01                  -4.238248e-02
# 75%               6.145610e-01                   6.108103e-01
# max               3.244257e+00                   2.398779e+00
#
#        business_climate  scoreeasedoingbusiness           buf          invf  \
# count      2.170000e+02            2.170000e+02  2.170000e+02  2.170000e+02
# mean      -1.739520e-17           -1.125572e-17  2.430212e-18  9.439454e-17
# std        1.002312e+00            1.002312e+00  1.002312e+00  1.002312e+00
# min       -2.578254e+00           -2.502177e+00 -3.357308e+00 -2.872423e+00
# 25%       -6.557780e-01           -7.295256e-01 -1.832865e-02 -1.652805e-01
# 50%       -1.455203e-01           -6.186958e-02 -1.832865e-02 -1.652805e-01
# 75%        7.009108e-01            6.730062e-01 -1.832865e-02 -1.652805e-01
# max        1.901864e+00            2.507095e+00  3.009916e+00  2.769581e+00
#
#             finfree  stock market
# count  2.170000e+02  2.170000e+02
# mean  -9.951077e-17 -8.697600e-18
# std    1.002312e+00  1.002312e+00
# min   -2.615134e+00 -2.269569e+00
# 25%   -1.936323e-01 -6.290005e-01
# 50%   -1.936323e-01 -2.881229e-02
# 75%   -1.936323e-01  6.576492e-01
# max    2.584695e+00  2.455562e+00

# %% [markdown]
# # we train/fit our model and evaluate it

# %%
from sklearn.metrics import r2_score

y_pred_train = lm.predict(X_train_scaled_df)
y_pred_test  = lm.predict(X_test_scaled_df)
#r2_score(y_train, y_pred_train)


#from sklearn.metrics import r2_score
#y_pred = lm.predict(X)
#r2_score(y, y_pred)

# %%
fig, ax = plt.subplots(2,2,figsize=(20,10))
sns.scatterplot(x=y_train, y=y_pred_train, ax = ax[0,0])
sns.histplot(x=y_train-y_pred_train, ax = ax[0,1], bins = 50)
ax[0,0].plot(y_train, y_train, color = "black")
sns.scatterplot(x=y_test, y=y_pred_test, ax = ax[1,0])
sns.histplot(x=y_test-y_pred_test, ax = ax[1,1], bins=50)
ax[1,0].plot(y_test, y_test, color="black")
plt.show()

# %%
fig, ax = plt.subplots()
sns.scatterplot(X_train_scaled_df['gross_fixed_capital_formation'].values,y_train)
plt.show()
# Out:
# C:\Users\NON\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(x=np.sqrt(X_train['gross_fixed_capital_formation']),y=y_train)
plt.show()
# Out:
# C:\Users\NON\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [raw]
# powertransformer.lambdas_

# %% [markdown]
# # Evaluation of the TEST portion of the data, that we did not use for training.

# %%
y_pred_test = lm.predict(X_test_scaled_df)
r2_score(y_test, y_pred_test)
# Out:
# 0.643281651701102

# %%
#regression_line = lm.intercept_ + lm.coef_[0]*numeric_FDI3['stock market'] # b_0 + b_1 * x
#plt.plot(numeric_FDI3['stock market'], regression_line, c = 'orange')
#sns.scatterplot(x='stock market',y='fdi',data=numeric_FDI3)
#plt.show()

# %% [markdown]
# # Description

# %%
#R2.
#MSE.
#RMSE.
#MAE.
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

lm = linear_model.LinearRegression()
lm.fit(X,y)
print(round(lm.intercept_,1))
print(lm.coef_.round(1))
print("r^2: ",round(lm.score(X_train_scaled,y_train),2))
# Out:
# -0.3
# [0.1]
# r^2:  0.12

# %% [markdown]
# # Checking linearity

# %%
np.random.seed(29)
x = np.random.randn(200)

# %%
y = x * 10 + np.random.randn(200) * 2

# %%
numeric_FDI4 = pd.DataFrame([x, y]).T
numeric_FDI4.columns = ['x', 'y']

# %%
sns.lmplot(x="x", y="y", data=numeric_FDI4, order=1)
plt.ylabel('fdi')
plt.xlabel('stock market')
# Out:
# Text(0.5, 20.80000000000002, 'stock market')

# %% [markdown]
# # checking relation

# %%
import scipy.stats as st

# %%
numeric_FDI3
# Out:
#           fdi  commercial_opening_rate  exchange_rate  \
# 0   -0.444693                 0.091316       0.587494
# 1   -0.431908                 0.305318       0.619904
# 2   -0.444369                 0.414890       0.648266
# 3   -0.436306                 0.480856       0.647921
# 4   -0.410158                 0.455876       0.646282
# ..        ...                      ...            ...
# 325 -0.043602                 0.022737      -1.213818
# 326  0.116868                 0.012928      -1.086020
# 327 -0.026669                 0.009179      -1.023403
# 328 -0.093661                 0.011055      -0.909239
# 329 -0.051258                 0.010118      -0.738744
#
#      gross_fixed_capital_formation  business_climate  scoreeasedoingbusiness  \
# 0                        -0.774379         -1.417695                0.661596
# 1                        -0.707284         -1.895417                0.661596
# 2                        -0.639883         -1.055946                0.661596
# 3                        -0.590864         -2.088493                0.661596
# 4                        -0.524810         -2.399586                0.661596
# ..                             ...               ...                     ...
# 325                       1.021005          1.063682                2.190009
# 326                       1.072169          0.840255                1.490001
# 327                       1.084916          0.876499                1.092581
# 328                       1.130210          0.759630                0.973696
# 329                       1.126836          0.704780                1.080960
#
#           buf      invf   finfree  stock market
# 0   -1.696496 -0.079910  2.400019     -1.081706
# 1   -1.696496 -0.079910  2.400019     -1.580889
# 2    0.325340  1.271784  2.400019     -1.517545
# 3    0.294923  0.582550  1.043553     -1.061439
# 4    0.011750  0.582550  1.043553     -0.943724
# ..        ...       ...       ...           ...
# 325  0.055768 -0.079910 -0.071074     -0.402052
# 326  0.055768 -0.079910 -0.071074     -0.470490
# 327  0.055768 -0.079910 -0.071074     -0.567819
# 328  0.055768 -0.079910 -0.071074     -0.274145
# 329  0.055768 -0.079910 -0.071074     -0.595492
#
# [290 rows x 10 columns]

# %%
matrix_donors = numeric_FDI3['fdi']
matrix_donors
# Out:
# 0     -0.444693
# 1     -0.431908
# 2     -0.444369
# 3     -0.436306
# 4     -0.410158
#          ...
# 325   -0.043602
# 326    0.116868
# 327   -0.026669
# 328   -0.093661
# 329   -0.051258
# Name: fdi, Length: 290, dtype: float64

# %%
FDI4 = ( numeric_FDI3['stock market'] ,  numeric_FDI3['fdi'], margins = False)
FDI4
# Out:
# fdi           -0.465033  -0.463561  -0.463301  -0.460892  -0.459917  \
# stock market
# -2.359208             0          0          0          0          0
# -2.355461             0          0          0          0          0
# -2.355391             0          0          0          0          0
# -2.353515             0          0          0          0          0
# -2.351350             0          0          0          0          0
# ...                 ...        ...        ...        ...        ...
#  2.312726             0          0          0          0          0
#  2.328118             0          0          0          0          0
#  2.399625             0          0          0          0          0
#  2.472174             0          0          0          0          0
#  2.573010             0          0          0          0          0
#
# fdi           -0.459837  -0.457060  -0.456806  -0.456438  -0.447075  ...  \
# stock market                                                         ...
# -2.359208             0          0          0          0          0  ...
# -2.355461             0          0          0          0          0  ...
# -2.355391             0          0          0          0          0  ...
# -2.353515             0          0          0          0          0  ...
# -2.351350             0          0          0          0          0  ...
# ...                 ...        ...        ...        ...        ...  ...
#  2.312726             0          0          0          0          0  ...
#  2.328118             0          0          0          0          0  ...
#  2.399625             0          0          0          0          0  ...
#  2.472174             0          0          0          0          0  ...
#  2.573010             0          0          0          0          0  ...
#
# fdi            0.268795   0.271531   0.291692   0.326676   0.345767  \
# stock market
# -2.359208             0          0          0          0          0
# -2.355461             0          0          0          0          0
# -2.355391             0          0          0          0          0
# -2.353515             0          0          0          0          0
# -2.351350             0          0          0          0          0
# ...                 ...        ...        ...        ...        ...
#  2.312726             0          0          0          0          0
#  2.328118             0          1          0          0          0
#  2.399625             0          0          0          0          0
#  2.472174             0          0          0          0          0
#  2.573010             0          0          0          0          0
#
# fdi            0.429047   0.436222   0.447487   0.465327   0.468611
# stock market
# -2.359208             0          0          0          0          0
# -2.355461             0          0          0          0          0
# -2.355391             0          0          0          0          0
# -2.353515             0          0          0          0          0
# -2.351350             0          0          0          0          0
# ...                 ...        ...        ...        ...        ...
#  2.312726             0          0          0          0          0
#  2.328118             0          0          0          0          0
#  2.399625             0          0          0          0          0
#  2.472174             0          0          0          0          0
#  2.573010             0          0          0          0          0
#
# [290 rows x 290 columns]

# %% [markdown]
# # compute chi2

# %%
st.chi2_contingency(FDI4)
# Out:
# (83810.0,
#  0.23949637231211704,
#  83521,
#  array([[0.00344828, 0.00344828, 0.00344828, ..., 0.00344828, 0.00344828,
#          0.00344828],
#         [0.00344828, 0.00344828, 0.00344828, ..., 0.00344828, 0.00344828,
#          0.00344828],
#         [0.00344828, 0.00344828, 0.00344828, ..., 0.00344828, 0.00344828,
#          0.00344828],
#         ...,
#         [0.00344828, 0.00344828, 0.00344828, ..., 0.00344828, 0.00344828,
#          0.00344828],
#         [0.00344828, 0.00344828, 0.00344828, ..., 0.00344828, 0.00344828,
#          0.00344828],
#         [0.00344828, 0.00344828, 0.00344828, ..., 0.00344828, 0.00344828,
#          0.00344828]]))

# %% [raw]
# #Ho: no relationship , here the pvalue is 0.2394963723121170
#
# #pvalue > 0.05 so we accept the null hypothesis there is no relationship between stock market and fdi

# %% [markdown]
# # CHEcKING Multicollinearity and  Variance Inflation Factor

# %%
sns.heatmap(numeric_FDI3.corr(), annot=True)
plt.show()

# %% [markdown]
# #we suspect that fdi correlated with the other

# %%
numeric_FDI3['total'] = numeric_FDI3['commercial_opening_rate'] +numeric_FDI3['gross_fixed_capital_formation'] +numeric_FDI3['business_climate'] +numeric_FDI3['scoreeasedoingbusiness'] +numeric_FDI3['buf'] +numeric_FDI3['invf']+numeric_FDI3['finfree']+numeric_FDI3['stock market'] 
numeric_FDI3.head()
# Out:
#         fdi  commercial_opening_rate  exchange_rate  \
# 0 -0.444693                 0.091316       0.587494
# 1 -0.431908                 0.305318       0.619904
# 2 -0.444369                 0.414890       0.648266
# 3 -0.436306                 0.480856       0.647921
# 4 -0.410158                 0.455876       0.646282
#
#    gross_fixed_capital_formation  business_climate  scoreeasedoingbusiness  \
# 0                      -0.774379         -1.417695                0.661596
# 1                      -0.707284         -1.895417                0.661596
# 2                      -0.639883         -1.055946                0.661596
# 3                      -0.590864         -2.088493                0.661596
# 4                      -0.524810         -2.399586                0.661596
#
#         buf      invf   finfree  stock market     total
# 0 -1.696496 -0.079910  2.400019     -1.081706 -1.897255
# 1 -1.696496 -0.079910  2.400019     -1.580889 -2.593063
# 2  0.325340  1.271784  2.400019     -1.517545  1.860255
# 3  0.294923  0.582550  1.043553     -1.061439 -0.677317
# 4  0.011750  0.582550  1.043553     -0.943724 -1.112796

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
y = numeric_FDI3['fdi']
X = numeric_FDI3[['commercial_opening_rate','gross_fixed_capital_formation','business_climate','scoreeasedoingbusiness','buf','invf','finfree','stock market']] 
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
LR = LinearRegression().fit(X_train,y_train)
