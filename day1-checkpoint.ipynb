# %% [markdown]
# # Loading libraries

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# # Importing data

# %%
FDI2 = pd.read_excel('FDI2.xlsx')

# %% [markdown]
# # Exploring data

# %%
FDI2.head()
# Out:
#   payscode  codepays  Année           ide          toc        tcr  \
# 0      BGD         1   2004  4.489054e+08  38953960.63  59.512658
# 1      BGD         1   2005  7.605043e+08  51935441.53  64.327475
# 2      BGD         1   2006  4.565232e+08  59714312.41  68.933233
# 3      BGD         1   2007  6.510297e+08  64798835.89  68.874875
# 4      BGD         1   2008  1.328423e+09  62836842.93  68.598275
#
#           fbcf  climatdaffaire  scoreeasedoingbusiness       caff    edb  \
# 0  18286460936       47.380000                    70.0  63.380000  66.00
# 1  20071885132       42.400000                    70.0  70.066667  61.30
# 2  22056583775       50.916667                    70.0  72.800000  63.90
# 3  23632938587       40.266667                    70.0  69.450000  65.36
# 4  25952536543       36.650000                    70.0  71.450000  67.00
#
#     crp   BUF  invf  finfree         CM
# 0  0.11  55.0  50.0     70.0  10.671695
# 1  0.06  55.0  50.0     70.0   4.751541
# ...

# %%
FDI2.tail()
# Out:
#     payscode  codepays  Année           ide          toc       tcr  \
# 325      TUR        22   2014  1.333700e+10  35361166.84  2.188542
# 326      TUR        22   2015  1.927400e+10  34868314.46  2.720009
# 327      TUR        22   2016  1.395000e+10  34681331.76  3.020135
# 328      TUR        22   2017  1.154600e+10  34774823.11  3.648133
# 329      TUR        22   2018  1.306100e+10  34728077.44  4.828370
#
#              fbcf  climatdaffaire  scoreeasedoingbusiness  caff  edb  crp  \
# 325  292106000000       68.933333                  83.400   NaN  NaN  NaN
# 326  319228000000       67.200000                  77.500   NaN  NaN  NaN
# 327  326401000000       67.483333                  73.980   NaN  NaN  NaN
# 328  353331000000       66.566667                  72.900   NaN  NaN  NaN
# 329  351244000000       66.133333                  73.875   NaN  NaN  NaN
#
#      BUF  invf  finfree         CM
# 325  NaN   NaN      NaN  23.405529
# 326  NaN   NaN      NaN  21.851067
# ...

# %% [markdown]
# # rename columns

# %%
FDI2.rename(columns = {'ide' : 'fdi', 'toc' : 'commercial_opening_rate'}, inplace = True)

# %%
FDI2.rename(columns = {'tcr' : 'Exchange_rate' , 'fbcf' : 'gross_fixed_capital_formation' ,  'climatdaffaire' : 'business_climate',   'cm' : 'stock_market'}, inplace = True)

# %%
display(FDI2)
# Out:
#     payscode  codepays  Année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      Exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# ...

# %% [markdown]
# I decided to drop the following columns because of ...

# %%
FDI3= FDI2.drop(['caff', 'edb', 'crp'], axis=1)

# %% [markdown]
# # lower case the variables

# %%
FDI3.columns = list(map(lambda x: x.lower(), FDI3.columns))
FDI3.columns.unique()
# Out:
# Index(['payscode', 'codepays', 'année', 'fdi', 'commercial_opening_rate',
#        'exchange_rate', 'gross_fixed_capital_formation', 'business_climate',
#        'scoreeasedoingbusiness', 'buf', 'invf', 'finfree', 'cm'],
#       dtype='object')

# %% [markdown]
# # exploring the data afer modification

# %%
FDI3.shape
# Out:
# (330, 13)

# %%
FDI3.dtypes
# Out:
# payscode                          object
# codepays                           int64
# année                              int64
# fdi                              float64
# commercial_opening_rate          float64
# exchange_rate                    float64
# gross_fixed_capital_formation      int64
# business_climate                 float64
# scoreeasedoingbusiness           float64
# buf                              float64
# invf                             float64
# finfree                          float64
# cm                               float64
# dtype: object

# %%
FDI3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   payscode                       330 non-null    object
#  1   codepays                       330 non-null    int64
#  2   année                          330 non-null    int64
#  3   fdi                            330 non-null    float64
#  4   commercial_opening_rate        330 non-null    float64
#  5   exchange_rate                  330 non-null    float64
#  6   gross_fixed_capital_formation  330 non-null    int64
#  7   business_climate               330 non-null    float64
#  8   scoreeasedoingbusiness         330 non-null    float64
#  9   buf                            165 non-null    float64
#  10  invf                           165 non-null    float64
#  11  finfree                        165 non-null    float64
# ...

# %%
list (FDI3 ['fdi'].unique())
# Out:
# [448905400.7,
#  760504265.8,
#  456523167.7,
#  651029738.1,
#  1328422987.0,
#  901286583.1,
#  1232258247.0,
#  1264725163.0,
#  1584403460.0,
#  2602962095.0,
#  2539190940.0,
#  2831152765.0,
#  2332724781.0,
#  1810395804.0,
#  2940222420.0,
#  3072550962.0,
#  4098122931.0,
#  7874476255.0,
#  13875270457.0,
#  10296720634.0,
#  3896664559.0,
#  1842900000.0,
#  2103810000.0,
#  1788110000.0,
#  1989040000.0,
#  1093600000.0,
#  2609370000.0,
#  1562800000.0,
#  2020340000.0,
#  1222580000.0,
#  18181190855.0,
#  15459981604.0,
#  19378093068.0,
#  44579492464.0,
#  50716402711.0,
#  31480932200.0,
#  82389933624.0,
#  102427000000.0,
#  92568379495.0,
#  75211028087.0,
#  87713987797.0,
#  60334050668.0,
#  73377909022.0,
#  68885072606.0,
#  78162572753.0,
#  68117272181.0,
#  104109000000.0,
#  124082000000.0,
#  156249000000.0,
#  171535000000.0,
#  131057000000.0,
#  243703000000.0,
#  280072000000.0,
#  241214000000.0,
#  290928000000.0,
#  268097000000.0,
# ...

# %%
FDI3 ['fdi'].unique()
# Out:
# array([ 4.48905401e+08,  7.60504266e+08,  4.56523168e+08,  6.51029738e+08,
#         1.32842299e+09,  9.01286583e+08,  1.23225825e+09,  1.26472516e+09,
#         1.58440346e+09,  2.60296210e+09,  2.53919094e+09,  2.83115276e+09,
#         2.33272478e+09,  1.81039580e+09,  2.94022242e+09,  3.07255096e+09,
#         4.09812293e+09,  7.87447626e+09,  1.38752705e+10,  1.02967206e+10,
#         3.89666456e+09,  1.84290000e+09,  2.10381000e+09,  1.78811000e+09,
#         1.98904000e+09,  1.09360000e+09,  2.60937000e+09,  1.56280000e+09,
#         2.02034000e+09,  1.22258000e+09,  1.81811909e+10,  1.54599816e+10,
#         1.93780931e+10,  4.45794925e+10,  5.07164027e+10,  3.14809322e+10,
#         8.23899336e+10,  1.02427000e+11,  9.25683795e+10,  7.52110281e+10,
#         8.77139878e+10,  6.03340507e+10,  7.33779090e+10,  6.88850726e+10,
#         7.81625728e+10,  6.81172722e+10,  1.04109000e+11,  1.24082000e+11,
# ...

# %% [markdown]
# # cheking missing values

# %%
FDI3.isna().sum()
# Out:
# payscode                           0
# codepays                           0
# année                              0
# fdi                                0
# commercial_opening_rate            0
# exchange_rate                      0
# gross_fixed_capital_formation      0
# business_climate                   0
# scoreeasedoingbusiness             0
# buf                              165
# invf                             165
# finfree                          165
# cm                                 0
# dtype: int64

# %% [markdown]
# # Replacing the NAN values by the mean

# %%
FDI3[(FDI3['buf'].isna() == True) & (FDI3['invf'].isna()==True) & (FDI3['finfree'].isna()==True)]
display (FDI3)
# Out:
#     payscode  codepays  année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# ...

# %%
FDI3['buf'].fillna(FDI3['buf'].mean(), inplace=True)

# %%
display(FDI3)
# Out:
#     payscode  codepays  année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# ...

# %%
FDI3['invf'].fillna(FDI3['invf'].mean(), inplace=True)

# %%
FDI3['finfree'].fillna(FDI3['finfree'].mean(), inplace=True)

# %%
display(FDI3)
# Out:
#     payscode  codepays  année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# ...

# %% [markdown]
# # Check again the missing values

# %%
FDI3.isna().sum()
# Out:
# payscode                         0
# codepays                         0
# année                            0
# fdi                              0
# commercial_opening_rate          0
# exchange_rate                    0
# gross_fixed_capital_formation    0
# business_climate                 0
# scoreeasedoingbusiness           0
# buf                              0
# invf                             0
# finfree                          0
# cm                               0
# dtype: int64

# %% [markdown]
# we have here a clean data

# %% [markdown]
# # describing the data

# %%
FDI3.describe().T
# Out:
#                                count          mean           std  \
# codepays                       330.0  1.150000e+01  6.353923e+00
# année                          330.0  2.011000e+03  4.327055e+00
# fdi                            330.0  1.828205e+10  4.312849e+10
# commercial_opening_rate        330.0  6.454303e+07  1.170231e+08
# exchange_rate                  330.0  1.331637e+03  4.823952e+03
# gross_fixed_capital_formation  330.0  2.416401e+11  6.508859e+11
# business_climate               330.0  5.992981e+01  8.639142e+00
# scoreeasedoingbusiness         330.0  6.275875e+01  1.065464e+01
# buf                            330.0  6.781606e+01  7.192081e+00
# invf                           330.0  5.053030e+01  1.610964e+01
# finfree                        330.0  4.896970e+01  1.238316e+01
# cm                             330.0  4.147970e+01  3.298583e+01
#
#                                         min           25%           50%  \
# ...

# %% [markdown]
# # Log transormation

# %%
FDI3['log_fdi'] = np.log(FDI3['fdi'])
print(FDI3)
# Out:
#     payscode  codepays  année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# ...

# %%
def log(FDI3):
    for i in cols:
        FDI3['i'] = np.log(FDI3['i']);
        plt.show()
    return i

log_transf = log.apply(log)
log_transf.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37516/148127151.py in <module>
#       5     return i
#       6
# ----> 7 log_transf = log.apply(log)
#       8 log_transf.value_counts()
#
# AttributeError: 'function' object has no attribute 'apply'

# %%
FDI3['log_commercial_opening_rate']=  np.log(FDI3['commercial_opening_rate'])
print(FDI3)
# Out:
#     payscode  codepays  année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# ...

# %%
FDI3['log_exchange_rate']=  np.log(FDI3['exchange_rate'])

# %%
FDI3['log_gross_fixed_capital_formation']=  np.log(FDI3['gross_fixed_capital_formation'])

# %%
numericals = FDI3.select_dtypes(np.number)
display(numericals.head())
categoricals = FDI3.select_dtypes(np.object)
display(categoricals.head())
# Out:
#    codepays  année           fdi  commercial_opening_rate  exchange_rate  \
# 0         1   2004  4.489054e+08              38953960.63      59.512658
# 1         1   2005  7.605043e+08              51935441.53      64.327475
# 2         1   2006  4.565232e+08              59714312.41      68.933233
# 3         1   2007  6.510297e+08              64798835.89      68.874875
# 4         1   2008  1.328423e+09              62836842.93      68.598275
#
#    gross_fixed_capital_formation  business_climate  scoreeasedoingbusiness  \
# 0                    18286460936         47.380000                    70.0
# 1                    20071885132         42.400000                    70.0
# 2                    22056583775         50.916667                    70.0
# 3                    23632938587         40.266667                    70.0
# 4                    25952536543         36.650000                    70.0
#
# ...

# %%
for col in numericals.columns :
    print("The number of unique values for",col, "is :", np.log(FDI3['col'])
# Out:
#   File "C:\Users\NON\AppData\Local\Temp/ipykernel_37516/2959010991.py", line 2
#     print("The number of unique values for",col, "is :", np.log(FDI3['col'])
#                                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
def FDI3_LOG(x):
    if (x in numericals) :
        return np.log(FDI3['x']) 
    else :
        return x
    return x

# %%
FDI3['business_climate'] = FDI3['business_climate'].apply(FDI3_LOG)
FDI3['business_climate'].unique()
FDI3['fdi'] = FDI3['fdi'].apply(FDI3_LOG)
FDI3['fdi'].unique()
FDI3['commercial_opening_rate'] = FDI3['commercial_opening_rate'].apply(FDI3_LOG)
FDI3['commercial_opening_rate'].unique()
FDI3['exchange_rate'] = FDI3['exchange_rate'].apply(FDI3_LOG)
FDI3['exchange_rate'].unique()
FDI3['gross_fixed_capital_formation'] = FDI3['gross_fixed_capital_formation'].apply(FDI3_LOG)
FDI3['gross_fixed_capital_formation'].unique()
FDI3['invf'] = FDI3['invf'].apply(FDI3_LOG)
FDI3['invf'].unique()
FDI3['buf'] = FDI3['buf'].apply(FDI3_LOG)
FDI3['buf'].unique()
FDI3['finfree'] = FDI3['finfree'].apply(FDI3_LOG)
FDI3['finfree'].unique()
FDI3['cm'] = FDI3['cm'].apply(FDI3_LOG)
FDI3['cm'].unique()
# Out:
# array([1.06716952e+01, 4.75154113e+00, 5.36112382e+00, 1.09691658e+01,
#        1.27915601e+01, 2.04228933e+01, 3.61009742e+01, 3.70804527e+01,
#        3.44423479e+01, 3.44768696e+01, 3.13587742e+01, 3.29350828e+01,
#        3.18042431e+01, 3.45113913e+01, 2.82406788e+01, 1.07193260e+01,
#        1.70262538e+01, 3.00320750e+01, 4.87954295e+01, 1.63126168e+01,
#        1.66331931e+01, 1.46409145e+01, 1.43819378e+01, 1.45114261e+01,
#        1.44466820e+01, 1.44790541e+01, 1.44628680e+01, 1.44709610e+01,
#        1.44669145e+01, 1.44689378e+01, 4.93557986e+01, 5.32336043e+01,
#        6.41225727e+01, 9.80406995e+01, 3.49072399e+01, 8.02178650e+01,
#        6.99708225e+01, 4.69740757e+01, 4.97911999e+01, 4.12670849e+01,
#        3.43606022e+01, 2.72184107e+01, 4.22430722e+01, 4.62817884e+01,
#        4.86254512e+01, 2.28972279e+01, 1.75791009e+01, 4.16206405e+01,
#        1.26153075e+02, 3.87171346e+01, 7.00384246e+01, 6.61694080e+01,
# ...

# %%
display(FDI3)
# Out:
#     payscode  codepays  année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# ...

# %%
FDI3['log_business_climate']=  np.log(FDI3['business_climate'])

# %%
FDI3['log_scoreeasedoingbusiness']=  np.log(FDI3['scoreeasedoingbusiness'])

# %%
FDI3['log_buf']=  np.log(FDI3['buf'])

# %%
FDI3['log_invf']=  np.log(FDI3['invf'])
# Out:
# C:\Users\NON\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
FDI3['log_finfree']=  np.log(FDI3['finfree'])

# %%
FDI3['log_cm']=  np.log(FDI3['cm'])

# %%
display(FDI3)
# Out:
#     payscode  codepays  année           fdi  commercial_opening_rate  \
# 0        BGD         1   2004  4.489054e+08              38953960.63
# 1        BGD         1   2005  7.605043e+08              51935441.53
# 2        BGD         1   2006  4.565232e+08              59714312.41
# 3        BGD         1   2007  6.510297e+08              64798835.89
# 4        BGD         1   2008  1.328423e+09              62836842.93
# ..       ...       ...    ...           ...                      ...
# 325      TUR        22   2014  1.333700e+10              35361166.84
# 326      TUR        22   2015  1.927400e+10              34868314.46
# 327      TUR        22   2016  1.395000e+10              34681331.76
# 328      TUR        22   2017  1.154600e+10              34774823.11
# 329      TUR        22   2018  1.306100e+10              34728077.44
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0        59.512658                    18286460936         47.380000
# ...

# %% [markdown]
# # PLOTTING

# %%
import seaborn as sns
plt= sns.pairplot(FDI3[['log_fdi','log_cm','log_commercial_opening_rate','log_exchange_rate' ]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37516/1503970649.py in <module>
#       1 import seaborn as sns
#       2 plt= sns.pairplot(FDI3[['log_fdi','log_cm','log_commercial_opening_rate','log_exchange_rate' ]])
# ----> 3 plt.show()
#
# AttributeError: 'PairGrid' object has no attribute 'show'

# %%
numeric= FDI3._get_numeric_data()
display(numeric)
# Out:
#      codepays  année           fdi  commercial_opening_rate  exchange_rate  \
# 0           1   2004  4.489054e+08              38953960.63      59.512658
# 1           1   2005  7.605043e+08              51935441.53      64.327475
# 2           1   2006  4.565232e+08              59714312.41      68.933233
# 3           1   2007  6.510297e+08              64798835.89      68.874875
# 4           1   2008  1.328423e+09              62836842.93      68.598275
# ..        ...    ...           ...                      ...            ...
# 325        22   2014  1.333700e+10              35361166.84       2.188542
# 326        22   2015  1.927400e+10              34868314.46       2.720009
# 327        22   2016  1.395000e+10              34681331.76       3.020135
# 328        22   2017  1.154600e+10              34774823.11       3.648133
# 329        22   2018  1.306100e+10              34728077.44       4.828370
#
# ...

# %%
LOGTRANS= np.log(FDI3[])
display(LOGTRANS)
# Out:
#   File "C:\Users\NON\AppData\Local\Temp/ipykernel_37516/1971984544.py", line 1
#     LOGTRANS= np.log(FDI3[])
#                           ^
# SyntaxError: invalid syntax

# %%
numeric_FDI3 = FDI3.apply(lambda x: np.log(x) if np.issubdtype(x.dtype, np.number) else x)

# %%
display (numeric_FDI3)
# Out:
#     payscode  codepays     année        fdi  commercial_opening_rate  \
# 0        BGD  0.000000  7.602900  19.922323                17.477891
# 1        BGD  0.000000  7.603399  20.449492                17.765512
# 2        BGD  0.000000  7.603898  19.939150                17.905082
# 3        BGD  0.000000  7.604396  20.294066                17.986798
# 4        BGD  0.000000  7.604894  21.007258                17.956052
# ..       ...       ...       ...        ...                      ...
# 325      TUR  3.091042  7.607878  23.313808                17.381125
# 326      TUR  3.091042  7.608374  23.682023                17.367089
# 327      TUR  3.091042  7.608871  23.358745                17.361712
# 328      TUR  3.091042  7.609367  23.169605                17.364404
# 329      TUR  3.091042  7.609862  23.292897                17.363059
#
#      exchange_rate  gross_fixed_capital_formation  business_climate  \
# 0         4.086189                      23.629427          3.858200
# ...
